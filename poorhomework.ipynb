# %%
import pandas as pd
data=pd.read_excel('sz50.xlsx',None,index_col='datetime')
data.keys()
# Out:
# odict_keys(['600000.XSHG', '600016.XSHG', '600028.XSHG', '600029.XSHG', '600030.XSHG', '600036.XSHG', '600048.XSHG', '600050.XSHG', '600100.XSHG', '600104.XSHG', '600111.XSHG', '600340.XSHG', '600485.XSHG', '600518.XSHG', '600519.XSHG', '600547.XSHG', '600606.XSHG', '600837.XSHG', '600887.XSHG', '600919.XSHG', '600958.XSHG', '600999.XSHG', '601006.XSHG', '601088.XSHG', '601166.XSHG', '601169.XSHG', '601186.XSHG', '601198.XSHG', '601211.XSHG', '601229.XSHG', '601288.XSHG', '601318.XSHG', '601328.XSHG', '601336.XSHG', '601390.XSHG', '601398.XSHG', '601601.XSHG', '601628.XSHG', '601668.XSHG', '601688.XSHG', '601766.XSHG', '601788.XSHG', '601800.XSHG', '601818.XSHG', '601857.XSHG', '601881.XSHG', '601901.XSHG', '601985.XSHG', '601988.XSHG', '601989.XSHG'])

# %%
import pandas as pd
import numpy as np
import talib as ta
import warnings
warnings.filterwarnings('ignore')
stock=pd.read_excel('sz50.xlsx',sheetname='600036.XSHG',index_col='datetime')
array1=np.array(stock['close'])
print(ta.MA(array1,10)[-5:])
# Out:
# [108.35  108.741 109.176 110.102 111.666]

# %%
import pandas as pd
import numpy as np
import talib as ta
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
stock=pd.read_excel('sz50.xlsx',sheetname='600036.XSHG',index_col='datetime')
plt.figure(figsize=(15, 7))
plt.plot(stock.close)
rolling_mean = stock['close'].rolling(window=5,center=False).mean()
rolling_mean.plot()
plt.show()

# %%
import pandas as pd
import talib as ta
import numpy as np
import collections
import warnings
warnings.filterwarnings('ignore')
#计算50只股票的周期为5的ROCR100，生成dataframe
data=pd.read_excel('sz50.xlsx',None,index_col='datetime')
PN0= pd.Panel(data)
MI0=PN0.to_frame()
MI0_tp = PN0.transpose(2,1,0)
MI0_tp = PN0.transpose(2,1,0).to_frame()
Array=np.array(MI0_tp['close'])
real=ta.ROCR100(Array,timeperiod=5)
df=pd.DataFrame(real)

#计算前五只股票的ROCR100，（参数timeperiod=20）

#用一张图显示出来
plt.figure(figsize=(15, 7))
plt.plot(stock1.close)
#print(type(stock1.close))
plt.plot(stock2.close)
plt.legend(['600000.XSHG', '600016.XSHG', '600028.XSHG', '600029.XSHG', '600030.XSHG'])
plt.show()

    #Array=np.array(MI_tp['close'])
    #real_number=ta.ROCR100(Array,timeperiod=20)
    
    #dict_data[i]=stock['close']
    #frame_data=pd.DataFrame(real)
    #array1=np.array(frame_data)

#value_list=list(data.values())
#array1=np.array(value_list)
#real = ta.ROCR100(array1, timeperiod=5
# Out:
#                  0
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5        59.755151
# 6       125.263003
# 7        82.175503
# 8      1812.371134
# 9       228.513667
# 10      264.348579
# 11      175.515358
# 12     6964.516129
# 13      985.400076
# 14      228.876778
# 15       40.323109
# 16      107.773130
# 17      173.183626
# 18        0.468540
# 19        4.975571
# 20       33.446129
# 21        3.455663
# 22        1.978198
# 23      611.498973
# 24      154.692356
# 25       56.090652
# 26      184.456424
# 27       90.303030
# 28       39.607119
# 29       17.075131
# ...            ...
# 10055     5.906785
# 10056    44.706815
# 10057     4.952099
# 10058     1.590726
# 10059   842.191436
# 10060   116.490355
# 10061    48.068061
# 10062   120.668058
# 10063    67.971983
# 10064    22.566173
# 10065    26.602564
# 10066  1250.516224
# 10067    57.208766
# 10068   342.997658
# 10069    63.949636
# ...

# %%
from datetime import datetime
import talib.abstract as ta
data=pd.read_excel('sz50.xlsx',None,index_col='datetime')
PN= pd.Panel(data)
PN=PN.fillna(0)
pn_macd = pd.Panel({name: ta.MACD(value) for name, value in PN.iteritems()})
df_macd = pn_macd.transpose(2,1,0).to_frame()
df_macd
# Out:
#                                       macd  macdsignal   macdhist
# datetime            minor
# 2017-02-24 15:00:00 600000.XSHG   0.871114    1.197907  -0.326792
#                     600016.XSHG  -0.007077    0.265328  -0.272405
#                     600028.XSHG   0.028081    0.052015  -0.023934
#                     600029.XSHG   0.221787    0.132200   0.089587
#                     600030.XSHG   0.602873    0.620235  -0.017362
#                     600036.XSHG   1.291055    1.245643   0.045412
#                     600048.XSHG   2.316978    1.771997   0.544982
#                     600050.XSHG  -0.105248   -0.189278   0.084029
#                     600100.XSHG   0.453028    0.079491   0.373537
#                     600104.XSHG   2.271146    2.012658   0.258488
#                     600111.XSHG   2.429090    1.926561   0.502529
#                     600340.XSHG   8.025312    5.194384   2.830927
#                     600485.XSHG   0.000000    0.000000   0.000000
# ...
